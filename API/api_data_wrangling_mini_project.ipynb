# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'Xm3sDFRRbxD44ZsDTBxQ'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import json
from collections import Counter

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?limit=1&api_key=Xm3sDFRRbxD44ZsDTBxQ"

# %%
r = requests.get(url)
json_data = r.json()

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# dataset:  {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-12-01T14:48:09.907Z', 'newest_available_date': '2020-12-01', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': 1, 'transform': None, 'column_index': None, 'start_date': '2000-06-07', 'end_date': '2020-12-01', 'data': [['2020-12-01', 112.2, 112.2, 111.5, 112.0, None, 51.0, 5703.0, None, None, None]], 'collapse': None, 'order': None, 'database_id': 6129}

# %%
print(r.text)
# Out:
# {"dataset":{"id":10095370,"dataset_code":"AFX_X","database_code":"FSE","name":"Carl Zeiss Meditec (AFX_X)","description":"Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE0005313704","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2000-06-07","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"limit":1,"transform":null,"column_index":null,"start_date":"2000-06-07","end_date":"2020-12-01","data":[["2020-12-01",112.2,112.2,111.5,112.0,null,51.0,5703.0,null,null,null]],"collapse":null,"order":null,"database_id":6129}}

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %% [markdown]
# ANSWER Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD):

# %%
url_low = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?order=asc&start_date=2017-01-01&end_date=2017-12-31&column_index=3&api_key=Xm3sDFRRbxD44ZsDTBxQ"
url_high = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?order=asc&start_date=2017-01-01&end_date=2017-12-31&column_index=2&api_key=Xm3sDFRRbxD44ZsDTBxQ"
url_all = "https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?order=asc&start_date=2017-01-01&end_date=2017-12-31&api_key=Xm3sDFRRbxD44ZsDTBxQ"

r_low = requests.get(url_low)
r_high = requests.get(url_high)
r_all = requests.get(url_all)

json_rl = r_low.json()
json_rh = r_high.json()
json_all = r_all.json()

#print(json_rl['2017-12-29'])

for k in json_rl.keys():
    print(k + ': ', json_rl[k])
# Out:
# dataset:  {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-12-01T14:48:09.907Z', 'newest_available_date': '2020-12-01', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Low'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': 3, 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'data': [['2017-01-02', 34.99], ['2017-01-03', 35.34], ['2017-01-04', 34.75], ['2017-01-05', 34.73], ['2017-01-06', 34.91], ['2017-01-09', 34.43], ['2017-01-10', 34.46], ['2017-01-11', 34.84], ['2017-01-12', 34.31], ['2017-01-13', 34.6], ['2017-01-16', 34.56], ['2017-01-17', 34.79], ['2017-01-18', 34.8], ['2017-01-19', 34.42], ['2017-01-20', 34.05], ['2017-01-23', 33.62], ['2017-01-24', 33.85], ['20
# ...

# %%
low_extract = json_rl['dataset']['data']
high_extract = json_rh['dataset']['data']
all_extract = json_all['dataset']['data']

#extracts = low_extract + high_extract
print(type(low_extract))
print(type(high_extract))
print(type(all_extract))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
for i in all_extract:
    print (i)

# %%
a = json_rl['dataset']['data']
b = json_rh['dataset']['data']
c = json_all['dataset']['data']

print(type(json_all['dataset']))
      
print(min(a))
print(max(b))
# Out:
# <class 'dict'>
# ['2017-01-02', 34.99]
# ['2017-12-29', 51.94]

# %%
import operator
l = json_rl['dataset']
max_key = max(json_rl, key = json_rl.get)
print(max_key)
# Out:
# dataset

# %%
#print(json_rl['dataset']['data'])

lowdict = {}
highdict = {}

for d, l in a:
    lowdict = d, l
    print(lowdict)
for d, h in b:
    highdict = d, h
    print(highdict)
# Out:
# ('2017-01-02', 34.99)
# ('2017-01-03', 35.34)
# ('2017-01-04', 34.75)
# ('2017-01-05', 34.73)
# ('2017-01-06', 34.91)
# ('2017-01-09', 34.43)
# ('2017-01-10', 34.46)
# ('2017-01-11', 34.84)
# ('2017-01-12', 34.31)
# ('2017-01-13', 34.6)
# ('2017-01-16', 34.56)
# ('2017-01-17', 34.79)
# ('2017-01-18', 34.8)
# ('2017-01-19', 34.42)
# ('2017-01-20', 34.05)
# ('2017-01-23', 33.62)
# ('2017-01-24', 33.85)
# ('2017-01-25', 34.03)
# ('2017-01-26', 34.8)
# ('2017-01-27', 34.81)
# ('2017-01-30', 34.95)
# ('2017-01-31', 34.56)
# ('2017-02-01', 34.75)
# ('2017-02-02', 35.7)
# ('2017-02-03', 35.73)
# ('2017-02-06', 35.6)
# ('2017-02-07', 35.36)
# ('2017-02-08', 35.84)
# ('2017-02-09', 35.77)
# ('2017-02-10', 36.57)
# ('2017-02-13', 37.35)
# ('2017-02-14', 38.0)
# ('2017-02-15', 38.4)
# ('2017-02-16', 38.25)
# ('2017-02-17', 38.48)
# ('2017-02-20', 38.81)
# ('2017-02-21', 38.85)
# ('2017-02-22', 39.27)
# ('2017-02-23', 39.38)
# ('2017-02-24', 38.91)
# ('2017-02-27', 39.75)
# ...

# %%
def tuplesort(highdict):
   return(sorted(highdict, key = lambda x: float(x[1]), reverse = True))
   # Driver Code
print("Sort of Tuples By Its Float Number ::",tuplesort(highdict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-05162b612776> in <module>
#       2    return(sorted(highdict, key = lambda x: float(x[1]), reverse = True))
#       3    # Driver Code
# ----> 4 print("Sort of Tuples By Its Float Number ::",tuplesort(highdict))
#
# <ipython-input-77-05162b612776> in tuplesort(highdict)
#       1 def tuplesort(highdict):
# ----> 2    return(sorted(highdict, key = lambda x: float(x[1]), reverse = True))
#       3    # Driver Code
#       4 print("Sort of Tuples By Its Float Number ::",tuplesort(highdict))
#
# <ipython-input-77-05162b612776> in <lambda>(x)
#       1 def tuplesort(highdict):
# ----> 2    return(sorted(highdict, key = lambda x: float(x[1]), reverse = True))
#       3    # Driver Code
#       4 print("Sort of Tuples By Its Float Number ::",tuplesort(highdict))
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# Calculate what the highest and lowest opening prices were for the stock in this period.
#
# What was the largest change in any one day (based on High and Low price)?
#
# What was the largest change between any two days (based on Closing Price)?
#
# What was the average daily trading volume during this year?
