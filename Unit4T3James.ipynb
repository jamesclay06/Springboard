# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_t = properties.transpose().reset_index()
properties_t
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001                91449              82202.8
# 2     Barking & Dagenham  E09000002              50460.2              51085.8
# 3                 Barnet  E09000003              93284.5              93190.2
# 4                 Bexley  E09000004              64958.1              64787.9
# 5                  Brent  E09000005              71306.6              72022.3
# 6                Bromley  E09000006              81671.5              81657.6
# 7                 Camden  E09000007               120933               119509
# 8                Croydon  E09000008              69158.2              68951.1
# 9                 Ealing  E09000009              79885.9              80897.1
# 10               Enfield  E09000010              72514.7              73155.2
# 11             Greenwich  E09000011              62300.1              60993.3
# 12               Hackney  E09000012              61296.5              63187.1
# 13  Hammersmith & Fulham  E09000013               124903               122088
# 14              Haringey  E09000014              76287.6              78901.2
# 15                Harrow  E09000015              84769.5              83396.1
# 16              Havering  E09000016              68000.1              69393.5
# 17            Hillingdon  E09000017              73834.8              75031.1
# 18              Hounslow  E09000018              72231.7              71051.6
# 19             Islington  E09000019              92516.5              94342.4
# 20  Kensington & Chelsea  E09000020               182695               182345
# 21  Kingston upon Thames  E09000021              80875.8              81230.1
# 22               Lambeth  E09000022                67771              65381.5
# 23              Lewisham  E09000023              60491.3              60869.3
# 24                Merton  E09000024              82070.6              79982.7
# 25                Newham  E09000025              53539.3              53153.9
# 26             Redbridge  E09000026              72189.6              72141.6
# 27  Richmond upon Thames  E09000027               109326               111103
# 28             Southwark  E09000028              67885.2              64799.1
# 29                Sutton  E09000029                71537              70893.2
# 30         Tower Hamlets  E09000030              59865.2              62318.5
# 31        Waltham Forest  E09000031              61319.4              60252.1
# 32            Wandsworth  E09000032                88559                88641
# 33           Westminster  E09000033               133025               131468
# 34           Unnamed: 34        NaN                  NaN                  NaN
# 35          Inner London  E13000001                78252              75885.7
# 36          Outer London  E13000002              72958.8              72937.9
# 37           Unnamed: 37        NaN                  NaN                  NaN
# 38            NORTH EAST  E12000001              42076.4                42572
# 39            NORTH WEST  E12000002              43958.5              43925.4
# 40    YORKS & THE HUMBER  E12000003              44803.4              44528.8
# 41         EAST MIDLANDS  E12000004              45544.5              46051.6
# 42         WEST MIDLANDS  E12000005              48527.5              49341.3
# 43       EAST OF ENGLAND  E12000006              56701.6              56593.6
# 44                LONDON  E12000007              74435.8              72777.9
# 45            SOUTH EAST  E12000008              64018.9                63715
# 46            SOUTH WEST  E12000009              54705.2              54356.1
# 47           Unnamed: 47        NaN                  NaN                  NaN
# 48               England  E92000001              53202.8              53096.2
#
#                       3                    4                    5  \
# 0   1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1               79120.7              77101.2              84409.1
# 2                 51269              53133.5              53042.2
# 3               92247.5              90762.9                90258
# 4               64367.5              64277.7              63997.1
# 5               72015.8              72965.6                73704
# 6               81449.3              81124.4              81542.6
# 7                120282               120098               119929
# 8               68712.4                68610              68844.9
# 9               81379.9              82188.9              82077.1
# 10              72190.4              71442.9              70630.8
# 11              61377.8              61927.7                63513
# 12              63593.3              65139.6                66194
# 13               120636               121425               124434
# 14              78521.9              79545.6                79374
# 15              83416.2              83567.9              83853.7
# 16                69368              69444.3              68534.5
# 17              74188.7              73911.4              73117.1
# 18                72098              71890.3              72877.5
# 19              93465.9              93344.5              94346.4
# 20               182879               184177               191474
# 21              81111.5              81672.8              82123.5
# 22              66336.5              66388.8              69035.1
# 23                60288                59471              58551.4
# 24              80661.7              79990.5                80874
# 25              53458.3              54479.8                55804
# 26              72501.4              72228.6              72366.6
# 27               107325               106875               107708
# 28              65763.3              63073.6              64420.5
# 29              70306.8              69411.9              69759.2
# 30              63938.7              66233.2              66432.9
# 31              60871.1              60971.4              61494.2
# 32              87124.8                87026              86518.1
# 33               132260               133370               133911
# 34                  NaN                  NaN                  NaN
# 35              76591.6              76851.6              79129.2
# 36              72714.5              72591.9                72753
# 37                  NaN                  NaN                  NaN
# 38              42369.7              42095.8              43266.5
# 39              44434.9              44267.8              44223.6
# 40              45200.5              45614.3                44831
# 41              45383.8              46124.2                45878
# 42              49442.2              49455.9              50369.7
# 43              56171.2              56567.9              56479.8
# 44              73896.8              74455.3                75432
# 45              64113.6              64623.2              64530.4
# 46              53583.1                54786              54698.8
# 47                  NaN                  NaN                  NaN
# 48              53201.3              53590.9              53678.2
#
#                       6                    7                    8  ...  \
# 0   1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1               94900.5               110128               112329  ...
# 2               53700.3              52113.1              52232.2  ...
# 3               90107.2              91441.2              92361.3  ...
# 4               64252.3              63722.7              64432.6  ...
# 5               74310.5                74127                73547  ...
# 6               82382.8              82898.5              82054.4  ...
# 7                121887               124028               125530  ...
# 8               69052.5              69142.5              68993.4  ...
# 9               81630.7              82352.2              82706.7  ...
# 10              71348.3              71837.5              72237.9  ...
# 11              64751.6              65486.3              65076.4  ...
# 12              66921.2              68390.8              68096.8  ...
# 13               126175               124382               123625  ...
# 14              79956.4              80746.3              81217.7  ...
# 15              84173.2              84226.7              84430.6  ...
# 16              68464.6              68680.8              69023.4  ...
# 17                74005              74671.1              74967.9  ...
# 18              72331.1              73717.8              74479.9  ...
# 19              97428.9              98976.1              98951.2  ...
# 20               197266               197963               198037  ...
# 21              82205.7              82525.8              83342.8  ...
# 22              68881.2              69608.7                68840  ...
# 23              58041.4              58126.4              58151.3  ...
# 24              80704.9              81055.9              80781.1  ...
# 25              56067.8              55458.3              54709.4  ...
# 26              72279.4              72880.8              73275.2  ...
# 27               112865               114657               112320  ...
# 28              64155.8              67024.7              65525.9  ...
# 29              70125.2              70789.6              69958.4  ...
# 30              66232.2              64692.2              63472.3  ...
# 31              61547.8              61933.5              61916.4  ...
# 32              88114.3              89830.6              90560.7  ...
# 33               134562               133450               136582  ...
# 34                  NaN                  NaN                  NaN  ...
# 35              79969.2              80550.5              80597.6  ...
# 36              73189.4              73665.9              73691.1  ...
# 37                  NaN                  NaN                  NaN  ...
# 38              42315.3              43287.7              41899.1  ...
# 39                44113              44109.6              44193.7  ...
# 40              45392.6                45535              45111.5  ...
# 41                45680              46037.7              45922.5  ...
# 42              50100.4                49860              49598.5  ...
# 43              56288.9              57242.3              56732.4  ...
# 44              75606.2              75984.2              75529.3  ...
# 45                65511              65224.9              64851.6  ...
# 46              54420.2              54265.9              54365.7  ...
# 47                  NaN                  NaN                  NaN  ...
# 48              53735.2              53900.6              53600.3  ...
#
#                     301                  302                  303  \
# 0   2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
# 1                773679               792769               828658
# 2                303054               302748               301570
# 3                521612               516411               522770
# 4                336863               338817               339095
# 5                428436               469962               465941
# 6                435090               435392               433544
# 7                828713               821595               852239
# 8                372230               372715               370346
# 9                469324               468630               480946
# 10               389245               388562               391735
# 11               398299               398193               397263
# 12               552061               566021               577441
# 13               723312               738027               718906
# 14               553119               541002               546664
# 15               448104               451504               451311
# 16               361600               364140               365178
# 17               406012               404385               409495
# 18               412828               414209               411185
# 19               663552               666411               647626
# 20          1.24743e+06          1.31409e+06          1.34298e+06
# 21               490422               487914               487107
# 22               523715               520194               516709
# 23               409138               412211               412265
# 24               501305               502685               509706
# 25               365798               373430               374598
# 26               419793               417211               420312
# 27               660422               655140               655971
# 28               502328               494219               495690
# 29               371251               372622               373718
# 30               460993               473550               478002
# 31               443224               436242               435709
# 32               605153               610824               610531
# 33          1.01169e+06          1.01836e+06          1.00877e+06
# 34                  NaN                  NaN                  NaN
# 35               578370               582786               584052
# 36               423030               424187               425403
# 37                  NaN                  NaN                  NaN
# 38               127337               127213               128451
# 39               164606               164853               166509
# 40               164734               164531               165487
# 41               195365               193268               196403
# 42               201142               198970               200015
# 43               288702               288819               289075
# 44               476632               475368               482748
# 45               322252               318822               324063
# 46               257639               256659               260121
# 47                  NaN                  NaN                  NaN
# 48               247649               246640               250634
#
#                     304                  305                  306  \
# 0   2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00
# 1                900126               904803               869929
# 2                293553               292478               299074
# 3                529115               527494               517266
# 4                341997               338857               340723
# 5                469583               481570               485388
# 6                435345               426143               426899
# 7                863140               863897               850884
# 8                368793               370774               370456
# 9                481333               476675               466309
# 10               394040               392123               385629
# 11               398232               394191               386840
# 12               576961               577491               569407
# 13               689430               661399               682750
# 14               546755               550282               545541
# 15               450451               441979               438843
# 16               367496               366540               370841
# 17               403660               410204               405585
# 18               402369               396838               396324
# 19               638524               628646               643668
# 20          1.35411e+06          1.34231e+06          1.28305e+06
# 21               486945               484792               480281
# 22               506445               511629               518868
# 23               413783               419458               425098
# 24               511249               515996               521692
# 25               368576               371073               373949
# 26               419805               419015               413724
# 27               664165               685709               699844
# 28               497221               515173               507396
# 29               375309               369246               369053
# 30               465167               455222               442068
# 31               437132               441639               446692
# 32               610678               601848               588343
# 33          1.02327e+06               944395               956855
# 34                  NaN                  NaN                  NaN
# 35               580316               576810               574029
# 36               425799               424847               423842
# 37                  NaN                  NaN                  NaN
# 38               122881               127015               129200
# 39               163320               164226               169091
# 40               159851               164925               168421
# 41               195883               195000               199121
# 42               195479               198594               202478
# 43               290982               290033               291767
# 44               473948               470083               478038
# 45               325585               321852               322662
# 46               256531               255734               259599
# 47                  NaN                  NaN                  NaN
# 48               245938               246220               249298
#
#                     307                  308                  309  \
# 0   2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00
# 1                785001               794881               768714
# 2                303701               304696               301170
# 3                521528               525762               535663
# 4                343385               348046               345461
# 5                485619               496606               522546
# 6                430221               439342               444722
# 7                814615               826732               834938
# 8                375914               375618               381611
# 9                468656               485527               498874
# 10               387538               396986               400933
# 11               386665               389844               402314
# 12               586889               585433               607663
# 13               719546               740691               748041
# 14               548786               570028               571385
# 15               446469               455589               457591
# 16               375236               376242               373289
# 17               411528               411414               414548
# 18               396801               409465               415771
# 19               659397               689048               704189
# 20          1.31597e+06          1.35325e+06          1.35578e+06
# 21               487208               499805               507430
# 22               535983               539549               548789
# 23               423926               423538               432243
# 24               522400               527370               532169
# 25               378292               379881               379748
# 26               416655               421606               430934
# 27               694521               694353               695399
# 28               506968               502552               506807
# 29               370943               377985               383597
# 30               445848               452443               462753
# 31               445677               452930               455482
# 32               594035               614721               633709
# 33               916419               971306               938658
# 34                  NaN                  NaN                  NaN
# 35               578908               589531               597737
# 36               426805               432573               437848
# 37                  NaN                  NaN                  NaN
# 38               131272               132248               136659
# 39               171624               174483               175602
# 40               169181               172266               173032
# 41               201103               202542               203638
# 42               204203               205878               208714
# 43               293858               297786               303355
# 44               484709               492084               496736
# 45               326941               331706               336074
# 46               265373               266429               273163
# 47                  NaN                  NaN                  NaN
# 48               250179               252875               256774
#
#                     310
# 0   2020-10-01 00:00:00
# 1                721490
# 2                308583
# 3                536263
# 4                344254
# 5                518636
# 6                451013
# 7                857205
# 8                385488
# 9                518392
# 10               403170
# 11               406635
# 12               569792
# 13               716886
# 14               577636
# 15               459106
# 16               371260
# 17               419162
# 18               427832
# 19               693372
# 20          1.30134e+06
# 21               521343
# 22               536452
# 23               440519
# 24               561639
# 25               374954
# 26               429315
# 27               692638
# 28               512705
# 29               385190
# 30               470151
# 31               459387
# 32               638185
# 33               930164
# 34                  NaN
# 35               594393
# 36               442427
# 37                  NaN
# 38               136281
# 39               177796
# 40               177115
# 41               207605
# 42               210637
# 43               300744
# 44               490936
# 45               337412
# 46               274319
# 47                  NaN
# 48               259159
#
# [49 rows x 312 columns]

# %%
properties_t.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    301                  302                  303  \
# 0  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
# 1               773679               792769               828658
# 2               303054               302748               301570
# 3               521612               516411               522770
# 4               336863               338817               339095
#
#                    304                  305                  306  \
# 0  2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00
# 1               900126               904803               869929
# 2               293553               292478               299074
# 3               529115               527494               517266
# 4               341997               338857               340723
#
#                    307                  308                  309  \
# 0  2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00
# 1               785001               794881               768714
# 2               303701               304696               301170
# 3               521528               525762               535663
# 4               343385               348046               345461
#
#                    310
# 0  2020-10-01 00:00:00
# 1               721490
# 2               308583
# 3               536263
# 4               344254
#
# [5 rows x 312 columns]

# %%
properties_t.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            301,     302,     303,     304,     305,     306,     307,     308,
#            309,     310],
#       dtype='object', length=312)

# %%
properties_t.values
# Out:
# array([['Unnamed: 0', NaT, Timestamp('1995-01-01 00:00:00'), ...,
#         Timestamp('2020-08-01 00:00:00'),
#         Timestamp('2020-09-01 00:00:00'),
#         Timestamp('2020-10-01 00:00:00')],
#        ['City of London', 'E09000001', 91448.98487, ..., 794880.9192,
#         768713.6939, 721489.9694],
#        ['Barking & Dagenham', 'E09000002', 50460.2266, ..., 304696.0422,
#         301170.1313, 308583.0496],
#        ...,
#        ['SOUTH WEST', 'E12000009', 54705.1579, ..., 266428.9487,
#         273162.7818, 274319.4346],
#        ['Unnamed: 47', nan, nan, ..., nan, nan, nan],
#        ['England', 'E92000001', 53202.77128, ..., 252875.329,
#         256773.6342, 259158.7718]], dtype=object)

# %%
type(properties_t)
# Out:
# pandas.core.frame.DataFrame

# %%
properties_t.shape
# Out:
# (49, 312)

# %%
properties_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Columns: 312 entries, index to 310
# dtypes: object(312)
# memory usage: 119.6+ KB

# %%
properties_t.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
properties_t.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    301                  302                  303  \
# 0  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
# 1               773679               792769               828658
# 2               303054               302748               301570
# 3               521612               516411               522770
# 4               336863               338817               339095
#
#                    304                  305                  306  \
# 0  2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00
# 1               900126               904803               869929
# 2               293553               292478               299074
# 3               529115               527494               517266
# 4               341997               338857               340723
#
#                    307                  308                  309  \
# 0  2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00
# 1               785001               794881               768714
# 2               303701               304696               301170
# 3               521528               525762               535663
# 4               343385               348046               345461
#
#                    310
# 0  2020-10-01 00:00:00
# 1               721490
# 2               308583
# 3               536263
# 4               344254
#
# [5 rows x 312 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_t.columns = properties_t.iloc[0]
# Out:
#                    index          0        1        2        3        4  \
# 1         City of London  E09000001    91449  82202.8  79120.7  77101.2
# 2     Barking & Dagenham  E09000002  50460.2  51085.8    51269  53133.5
# 3                 Barnet  E09000003  93284.5  93190.2  92247.5  90762.9
# 4                 Bexley  E09000004  64958.1  64787.9  64367.5  64277.7
# 5                  Brent  E09000005  71306.6  72022.3  72015.8  72965.6
# 6                Bromley  E09000006  81671.5  81657.6  81449.3  81124.4
# 7                 Camden  E09000007   120933   119509   120282   120098
# 8                Croydon  E09000008  69158.2  68951.1  68712.4    68610
# 9                 Ealing  E09000009  79885.9  80897.1  81379.9  82188.9
# 10               Enfield  E09000010  72514.7  73155.2  72190.4  71442.9
# 11             Greenwich  E09000011  62300.1  60993.3  61377.8  61927.7
# 12               Hackney  E09000012  61296.5  63187.1  63593.3  65139.6
# 13  Hammersmith & Fulham  E09000013   124903   122088   120636   121425
# 14              Haringey  E09000014  76287.6  78901.2  78521.9  79545.6
# 15                Harrow  E09000015  84769.5  83396.1  83416.2  83567.9
# 16              Havering  E09000016  68000.1  69393.5    69368  69444.3
# 17            Hillingdon  E09000017  73834.8  75031.1  74188.7  73911.4
# 18              Hounslow  E09000018  72231.7  71051.6    72098  71890.3
# 19             Islington  E09000019  92516.5  94342.4  93465.9  93344.5
# 20  Kensington & Chelsea  E09000020   182695   182345   182879   184177
# 21  Kingston upon Thames  E09000021  80875.8  81230.1  81111.5  81672.8
# 22               Lambeth  E09000022    67771  65381.5  66336.5  66388.8
# 23              Lewisham  E09000023  60491.3  60869.3    60288    59471
# 24                Merton  E09000024  82070.6  79982.7  80661.7  79990.5
# 25                Newham  E09000025  53539.3  53153.9  53458.3  54479.8
# 26             Redbridge  E09000026  72189.6  72141.6  72501.4  72228.6
# 27  Richmond upon Thames  E09000027   109326   111103   107325   106875
# 28             Southwark  E09000028  67885.2  64799.1  65763.3  63073.6
# 29                Sutton  E09000029    71537  70893.2  70306.8  69411.9
# 30         Tower Hamlets  E09000030  59865.2  62318.5  63938.7  66233.2
# 31        Waltham Forest  E09000031  61319.4  60252.1  60871.1  60971.4
# 32            Wandsworth  E09000032    88559    88641  87124.8    87026
# 33           Westminster  E09000033   133025   131468   132260   133370
# 34           Unnamed: 34        NaN      NaN      NaN      NaN      NaN
# 35          Inner London  E13000001    78252  75885.7  76591.6  76851.6
# 36          Outer London  E13000002  72958.8  72937.9  72714.5  72591.9
# 37           Unnamed: 37        NaN      NaN      NaN      NaN      NaN
# 38            NORTH EAST  E12000001  42076.4    42572  42369.7  42095.8
# 39            NORTH WEST  E12000002  43958.5  43925.4  44434.9  44267.8
# 40    YORKS & THE HUMBER  E12000003  44803.4  44528.8  45200.5  45614.3
# 41         EAST MIDLANDS  E12000004  45544.5  46051.6  45383.8  46124.2
# 42         WEST MIDLANDS  E12000005  48527.5  49341.3  49442.2  49455.9
# 43       EAST OF ENGLAND  E12000006  56701.6  56593.6  56171.2  56567.9
# 44                LONDON  E12000007  74435.8  72777.9  73896.8  74455.3
# 45            SOUTH EAST  E12000008  64018.9    63715  64113.6  64623.2
# 46            SOUTH WEST  E12000009  54705.2  54356.1  53583.1    54786
# 47           Unnamed: 47        NaN      NaN      NaN      NaN      NaN
# 48               England  E92000001  53202.8  53096.2  53201.3  53590.9
#
#           5        6        7        8  ...          301          302  \
# 1   84409.1  94900.5   110128   112329  ...       773679       792769
# 2   53042.2  53700.3  52113.1  52232.2  ...       303054       302748
# 3     90258  90107.2  91441.2  92361.3  ...       521612       516411
# 4   63997.1  64252.3  63722.7  64432.6  ...       336863       338817
# 5     73704  74310.5    74127    73547  ...       428436       469962
# 6   81542.6  82382.8  82898.5  82054.4  ...       435090       435392
# 7    119929   121887   124028   125530  ...       828713       821595
# 8   68844.9  69052.5  69142.5  68993.4  ...       372230       372715
# 9   82077.1  81630.7  82352.2  82706.7  ...       469324       468630
# 10  70630.8  71348.3  71837.5  72237.9  ...       389245       388562
# 11    63513  64751.6  65486.3  65076.4  ...       398299       398193
# 12    66194  66921.2  68390.8  68096.8  ...       552061       566021
# 13   124434   126175   124382   123625  ...       723312       738027
# 14    79374  79956.4  80746.3  81217.7  ...       553119       541002
# 15  83853.7  84173.2  84226.7  84430.6  ...       448104       451504
# 16  68534.5  68464.6  68680.8  69023.4  ...       361600       364140
# 17  73117.1    74005  74671.1  74967.9  ...       406012       404385
# 18  72877.5  72331.1  73717.8  74479.9  ...       412828       414209
# 19  94346.4  97428.9  98976.1  98951.2  ...       663552       666411
# 20   191474   197266   197963   198037  ...  1.24743e+06  1.31409e+06
# 21  82123.5  82205.7  82525.8  83342.8  ...       490422       487914
# 22  69035.1  68881.2  69608.7    68840  ...       523715       520194
# 23  58551.4  58041.4  58126.4  58151.3  ...       409138       412211
# 24    80874  80704.9  81055.9  80781.1  ...       501305       502685
# 25    55804  56067.8  55458.3  54709.4  ...       365798       373430
# 26  72366.6  72279.4  72880.8  73275.2  ...       419793       417211
# 27   107708   112865   114657   112320  ...       660422       655140
# 28  64420.5  64155.8  67024.7  65525.9  ...       502328       494219
# 29  69759.2  70125.2  70789.6  69958.4  ...       371251       372622
# 30  66432.9  66232.2  64692.2  63472.3  ...       460993       473550
# 31  61494.2  61547.8  61933.5  61916.4  ...       443224       436242
# 32  86518.1  88114.3  89830.6  90560.7  ...       605153       610824
# 33   133911   134562   133450   136582  ...  1.01169e+06  1.01836e+06
# 34      NaN      NaN      NaN      NaN  ...          NaN          NaN
# 35  79129.2  79969.2  80550.5  80597.6  ...       578370       582786
# 36    72753  73189.4  73665.9  73691.1  ...       423030       424187
# 37      NaN      NaN      NaN      NaN  ...          NaN          NaN
# 38  43266.5  42315.3  43287.7  41899.1  ...       127337       127213
# 39  44223.6    44113  44109.6  44193.7  ...       164606       164853
# 40    44831  45392.6    45535  45111.5  ...       164734       164531
# 41    45878    45680  46037.7  45922.5  ...       195365       193268
# 42  50369.7  50100.4    49860  49598.5  ...       201142       198970
# 43  56479.8  56288.9  57242.3  56732.4  ...       288702       288819
# 44    75432  75606.2  75984.2  75529.3  ...       476632       475368
# 45  64530.4    65511  65224.9  64851.6  ...       322252       318822
# 46  54698.8  54420.2  54265.9  54365.7  ...       257639       256659
# 47      NaN      NaN      NaN      NaN  ...          NaN          NaN
# 48  53678.2  53735.2  53900.6  53600.3  ...       247649       246640
#
#             303          304          305          306          307  \
# 1        828658       900126       904803       869929       785001
# 2        301570       293553       292478       299074       303701
# 3        522770       529115       527494       517266       521528
# 4        339095       341997       338857       340723       343385
# 5        465941       469583       481570       485388       485619
# 6        433544       435345       426143       426899       430221
# 7        852239       863140       863897       850884       814615
# 8        370346       368793       370774       370456       375914
# 9        480946       481333       476675       466309       468656
# 10       391735       394040       392123       385629       387538
# 11       397263       398232       394191       386840       386665
# 12       577441       576961       577491       569407       586889
# 13       718906       689430       661399       682750       719546
# 14       546664       546755       550282       545541       548786
# 15       451311       450451       441979       438843       446469
# 16       365178       367496       366540       370841       375236
# 17       409495       403660       410204       405585       411528
# 18       411185       402369       396838       396324       396801
# 19       647626       638524       628646       643668       659397
# 20  1.34298e+06  1.35411e+06  1.34231e+06  1.28305e+06  1.31597e+06
# 21       487107       486945       484792       480281       487208
# 22       516709       506445       511629       518868       535983
# 23       412265       413783       419458       425098       423926
# 24       509706       511249       515996       521692       522400
# 25       374598       368576       371073       373949       378292
# 26       420312       419805       419015       413724       416655
# 27       655971       664165       685709       699844       694521
# 28       495690       497221       515173       507396       506968
# 29       373718       375309       369246       369053       370943
# 30       478002       465167       455222       442068       445848
# 31       435709       437132       441639       446692       445677
# 32       610531       610678       601848       588343       594035
# 33  1.00877e+06  1.02327e+06       944395       956855       916419
# 34          NaN          NaN          NaN          NaN          NaN
# 35       584052       580316       576810       574029       578908
# 36       425403       425799       424847       423842       426805
# 37          NaN          NaN          NaN          NaN          NaN
# 38       128451       122881       127015       129200       131272
# 39       166509       163320       164226       169091       171624
# 40       165487       159851       164925       168421       169181
# 41       196403       195883       195000       199121       201103
# 42       200015       195479       198594       202478       204203
# 43       289075       290982       290033       291767       293858
# 44       482748       473948       470083       478038       484709
# 45       324063       325585       321852       322662       326941
# 46       260121       256531       255734       259599       265373
# 47          NaN          NaN          NaN          NaN          NaN
# 48       250634       245938       246220       249298       250179
#
#             308          309          310
# 1        794881       768714       721490
# 2        304696       301170       308583
# 3        525762       535663       536263
# 4        348046       345461       344254
# 5        496606       522546       518636
# 6        439342       444722       451013
# 7        826732       834938       857205
# 8        375618       381611       385488
# 9        485527       498874       518392
# 10       396986       400933       403170
# 11       389844       402314       406635
# 12       585433       607663       569792
# 13       740691       748041       716886
# 14       570028       571385       577636
# 15       455589       457591       459106
# 16       376242       373289       371260
# 17       411414       414548       419162
# 18       409465       415771       427832
# 19       689048       704189       693372
# 20  1.35325e+06  1.35578e+06  1.30134e+06
# 21       499805       507430       521343
# 22       539549       548789       536452
# 23       423538       432243       440519
# 24       527370       532169       561639
# 25       379881       379748       374954
# 26       421606       430934       429315
# 27       694353       695399       692638
# 28       502552       506807       512705
# 29       377985       383597       385190
# 30       452443       462753       470151
# 31       452930       455482       459387
# 32       614721       633709       638185
# 33       971306       938658       930164
# 34          NaN          NaN          NaN
# 35       589531       597737       594393
# 36       432573       437848       442427
# 37          NaN          NaN          NaN
# 38       132248       136659       136281
# 39       174483       175602       177796
# 40       172266       173032       177115
# 41       202542       203638       207605
# 42       205878       208714       210637
# 43       297786       303355       300744
# 44       492084       496736       490936
# 45       331706       336074       337412
# 46       266429       273163       274319
# 47          NaN          NaN          NaN
# 48       252875       256774       259159
#
# [48 rows x 312 columns]

# %%
properties_t = properties_t.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT:'ID'})
properties_t.drop(0)
# Out:
# 0         London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001               91449             82202.8
# 2     Barking & Dagenham  E09000002             50460.2             51085.8
# 3                 Barnet  E09000003             93284.5             93190.2
# 4                 Bexley  E09000004             64958.1             64787.9
# 5                  Brent  E09000005             71306.6             72022.3
# 6                Bromley  E09000006             81671.5             81657.6
# 7                 Camden  E09000007              120933              119509
# 8                Croydon  E09000008             69158.2             68951.1
# 9                 Ealing  E09000009             79885.9             80897.1
# 10               Enfield  E09000010             72514.7             73155.2
# 11             Greenwich  E09000011             62300.1             60993.3
# 12               Hackney  E09000012             61296.5             63187.1
# 13  Hammersmith & Fulham  E09000013              124903              122088
# 14              Haringey  E09000014             76287.6             78901.2
# 15                Harrow  E09000015             84769.5             83396.1
# 16              Havering  E09000016             68000.1             69393.5
# 17            Hillingdon  E09000017             73834.8             75031.1
# 18              Hounslow  E09000018             72231.7             71051.6
# 19             Islington  E09000019             92516.5             94342.4
# 20  Kensington & Chelsea  E09000020              182695              182345
# 21  Kingston upon Thames  E09000021             80875.8             81230.1
# 22               Lambeth  E09000022               67771             65381.5
# 23              Lewisham  E09000023             60491.3             60869.3
# 24                Merton  E09000024             82070.6             79982.7
# 25                Newham  E09000025             53539.3             53153.9
# 26             Redbridge  E09000026             72189.6             72141.6
# 27  Richmond upon Thames  E09000027              109326              111103
# 28             Southwark  E09000028             67885.2             64799.1
# 29                Sutton  E09000029               71537             70893.2
# 30         Tower Hamlets  E09000030             59865.2             62318.5
# 31        Waltham Forest  E09000031             61319.4             60252.1
# 32            Wandsworth  E09000032               88559               88641
# 33           Westminster  E09000033              133025              131468
# 34           Unnamed: 34        NaN                 NaN                 NaN
# 35          Inner London  E13000001               78252             75885.7
# 36          Outer London  E13000002             72958.8             72937.9
# 37           Unnamed: 37        NaN                 NaN                 NaN
# 38            NORTH EAST  E12000001             42076.4               42572
# 39            NORTH WEST  E12000002             43958.5             43925.4
# 40    YORKS & THE HUMBER  E12000003             44803.4             44528.8
# 41         EAST MIDLANDS  E12000004             45544.5             46051.6
# 42         WEST MIDLANDS  E12000005             48527.5             49341.3
# 43       EAST OF ENGLAND  E12000006             56701.6             56593.6
# 44                LONDON  E12000007             74435.8             72777.9
# 45            SOUTH EAST  E12000008             64018.9               63715
# 46            SOUTH WEST  E12000009             54705.2             54356.1
# 47           Unnamed: 47        NaN                 NaN                 NaN
# 48               England  E92000001             53202.8             53096.2
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1              79120.7             77101.2             84409.1
# 2                51269             53133.5             53042.2
# 3              92247.5             90762.9               90258
# 4              64367.5             64277.7             63997.1
# 5              72015.8             72965.6               73704
# 6              81449.3             81124.4             81542.6
# 7               120282              120098              119929
# 8              68712.4               68610             68844.9
# 9              81379.9             82188.9             82077.1
# 10             72190.4             71442.9             70630.8
# 11             61377.8             61927.7               63513
# 12             63593.3             65139.6               66194
# 13              120636              121425              124434
# 14             78521.9             79545.6               79374
# 15             83416.2             83567.9             83853.7
# 16               69368             69444.3             68534.5
# 17             74188.7             73911.4             73117.1
# 18               72098             71890.3             72877.5
# 19             93465.9             93344.5             94346.4
# 20              182879              184177              191474
# 21             81111.5             81672.8             82123.5
# 22             66336.5             66388.8             69035.1
# 23               60288               59471             58551.4
# 24             80661.7             79990.5               80874
# 25             53458.3             54479.8               55804
# 26             72501.4             72228.6             72366.6
# 27              107325              106875              107708
# 28             65763.3             63073.6             64420.5
# 29             70306.8             69411.9             69759.2
# 30             63938.7             66233.2             66432.9
# 31             60871.1             60971.4             61494.2
# 32             87124.8               87026             86518.1
# 33              132260              133370              133911
# 34                 NaN                 NaN                 NaN
# 35             76591.6             76851.6             79129.2
# 36             72714.5             72591.9               72753
# 37                 NaN                 NaN                 NaN
# 38             42369.7             42095.8             43266.5
# 39             44434.9             44267.8             44223.6
# 40             45200.5             45614.3               44831
# 41             45383.8             46124.2               45878
# 42             49442.2             49455.9             50369.7
# 43             56171.2             56567.9             56479.8
# 44             73896.8             74455.3               75432
# 45             64113.6             64623.2             64530.4
# 46             53583.1               54786             54698.8
# 47                 NaN                 NaN                 NaN
# 48             53201.3             53590.9             53678.2
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1              94900.5              110128              112329  ...
# 2              53700.3             52113.1             52232.2  ...
# 3              90107.2             91441.2             92361.3  ...
# 4              64252.3             63722.7             64432.6  ...
# 5              74310.5               74127               73547  ...
# 6              82382.8             82898.5             82054.4  ...
# 7               121887              124028              125530  ...
# 8              69052.5             69142.5             68993.4  ...
# 9              81630.7             82352.2             82706.7  ...
# 10             71348.3             71837.5             72237.9  ...
# 11             64751.6             65486.3             65076.4  ...
# 12             66921.2             68390.8             68096.8  ...
# 13              126175              124382              123625  ...
# 14             79956.4             80746.3             81217.7  ...
# 15             84173.2             84226.7             84430.6  ...
# 16             68464.6             68680.8             69023.4  ...
# 17               74005             74671.1             74967.9  ...
# 18             72331.1             73717.8             74479.9  ...
# 19             97428.9             98976.1             98951.2  ...
# 20              197266              197963              198037  ...
# 21             82205.7             82525.8             83342.8  ...
# 22             68881.2             69608.7               68840  ...
# 23             58041.4             58126.4             58151.3  ...
# 24             80704.9             81055.9             80781.1  ...
# 25             56067.8             55458.3             54709.4  ...
# 26             72279.4             72880.8             73275.2  ...
# 27              112865              114657              112320  ...
# 28             64155.8             67024.7             65525.9  ...
# 29             70125.2             70789.6             69958.4  ...
# 30             66232.2             64692.2             63472.3  ...
# 31             61547.8             61933.5             61916.4  ...
# 32             88114.3             89830.6             90560.7  ...
# 33              134562              133450              136582  ...
# 34                 NaN                 NaN                 NaN  ...
# 35             79969.2             80550.5             80597.6  ...
# 36             73189.4             73665.9             73691.1  ...
# 37                 NaN                 NaN                 NaN  ...
# 38             42315.3             43287.7             41899.1  ...
# 39               44113             44109.6             44193.7  ...
# 40             45392.6               45535             45111.5  ...
# 41               45680             46037.7             45922.5  ...
# 42             50100.4               49860             49598.5  ...
# 43             56288.9             57242.3             56732.4  ...
# 44             75606.2             75984.2             75529.3  ...
# 45               65511             65224.9             64851.6  ...
# 46             54420.2             54265.9             54365.7  ...
# 47                 NaN                 NaN                 NaN  ...
# 48             53735.2             53900.6             53600.3  ...
#
# 0  2020-01-01 00:00:00 2020-02-01 00:00:00 2020-03-01 00:00:00  \
# 1               773679              792769              828658
# 2               303054              302748              301570
# 3               521612              516411              522770
# 4               336863              338817              339095
# 5               428436              469962              465941
# 6               435090              435392              433544
# 7               828713              821595              852239
# 8               372230              372715              370346
# 9               469324              468630              480946
# 10              389245              388562              391735
# 11              398299              398193              397263
# 12              552061              566021              577441
# 13              723312              738027              718906
# 14              553119              541002              546664
# 15              448104              451504              451311
# 16              361600              364140              365178
# 17              406012              404385              409495
# 18              412828              414209              411185
# 19              663552              666411              647626
# 20         1.24743e+06         1.31409e+06         1.34298e+06
# 21              490422              487914              487107
# 22              523715              520194              516709
# 23              409138              412211              412265
# 24              501305              502685              509706
# 25              365798              373430              374598
# 26              419793              417211              420312
# 27              660422              655140              655971
# 28              502328              494219              495690
# 29              371251              372622              373718
# 30              460993              473550              478002
# 31              443224              436242              435709
# 32              605153              610824              610531
# 33         1.01169e+06         1.01836e+06         1.00877e+06
# 34                 NaN                 NaN                 NaN
# 35              578370              582786              584052
# 36              423030              424187              425403
# 37                 NaN                 NaN                 NaN
# 38              127337              127213              128451
# 39              164606              164853              166509
# 40              164734              164531              165487
# 41              195365              193268              196403
# 42              201142              198970              200015
# 43              288702              288819              289075
# 44              476632              475368              482748
# 45              322252              318822              324063
# 46              257639              256659              260121
# 47                 NaN                 NaN                 NaN
# 48              247649              246640              250634
#
# 0  2020-04-01 00:00:00 2020-05-01 00:00:00 2020-06-01 00:00:00  \
# 1               900126              904803              869929
# 2               293553              292478              299074
# 3               529115              527494              517266
# 4               341997              338857              340723
# 5               469583              481570              485388
# 6               435345              426143              426899
# 7               863140              863897              850884
# 8               368793              370774              370456
# 9               481333              476675              466309
# 10              394040              392123              385629
# 11              398232              394191              386840
# 12              576961              577491              569407
# 13              689430              661399              682750
# 14              546755              550282              545541
# 15              450451              441979              438843
# 16              367496              366540              370841
# 17              403660              410204              405585
# 18              402369              396838              396324
# 19              638524              628646              643668
# 20         1.35411e+06         1.34231e+06         1.28305e+06
# 21              486945              484792              480281
# 22              506445              511629              518868
# 23              413783              419458              425098
# 24              511249              515996              521692
# 25              368576              371073              373949
# 26              419805              419015              413724
# 27              664165              685709              699844
# 28              497221              515173              507396
# 29              375309              369246              369053
# 30              465167              455222              442068
# 31              437132              441639              446692
# 32              610678              601848              588343
# 33         1.02327e+06              944395              956855
# 34                 NaN                 NaN                 NaN
# 35              580316              576810              574029
# 36              425799              424847              423842
# 37                 NaN                 NaN                 NaN
# 38              122881              127015              129200
# 39              163320              164226              169091
# 40              159851              164925              168421
# 41              195883              195000              199121
# 42              195479              198594              202478
# 43              290982              290033              291767
# 44              473948              470083              478038
# 45              325585              321852              322662
# 46              256531              255734              259599
# 47                 NaN                 NaN                 NaN
# 48              245938              246220              249298
#
# 0  2020-07-01 00:00:00 2020-08-01 00:00:00 2020-09-01 00:00:00  \
# 1               785001              794881              768714
# 2               303701              304696              301170
# 3               521528              525762              535663
# 4               343385              348046              345461
# 5               485619              496606              522546
# 6               430221              439342              444722
# 7               814615              826732              834938
# 8               375914              375618              381611
# 9               468656              485527              498874
# 10              387538              396986              400933
# 11              386665              389844              402314
# 12              586889              585433              607663
# 13              719546              740691              748041
# 14              548786              570028              571385
# 15              446469              455589              457591
# 16              375236              376242              373289
# 17              411528              411414              414548
# 18              396801              409465              415771
# 19              659397              689048              704189
# 20         1.31597e+06         1.35325e+06         1.35578e+06
# 21              487208              499805              507430
# 22              535983              539549              548789
# 23              423926              423538              432243
# 24              522400              527370              532169
# 25              378292              379881              379748
# 26              416655              421606              430934
# 27              694521              694353              695399
# 28              506968              502552              506807
# 29              370943              377985              383597
# 30              445848              452443              462753
# 31              445677              452930              455482
# 32              594035              614721              633709
# 33              916419              971306              938658
# 34                 NaN                 NaN                 NaN
# 35              578908              589531              597737
# 36              426805              432573              437848
# 37                 NaN                 NaN                 NaN
# 38              131272              132248              136659
# 39              171624              174483              175602
# 40              169181              172266              173032
# 41              201103              202542              203638
# 42              204203              205878              208714
# 43              293858              297786              303355
# 44              484709              492084              496736
# 45              326941              331706              336074
# 46              265373              266429              273163
# 47                 NaN                 NaN                 NaN
# 48              250179              252875              256774
#
# 0  2020-10-01 00:00:00
# 1               721490
# 2               308583
# 3               536263
# 4               344254
# 5               518636
# 6               451013
# 7               857205
# 8               385488
# 9               518392
# 10              403170
# 11              406635
# 12              569792
# 13              716886
# 14              577636
# 15              459106
# 16              371260
# 17              419162
# 18              427832
# 19              693372
# 20         1.30134e+06
# 21              521343
# 22              536452
# 23              440519
# 24              561639
# 25              374954
# 26              429315
# 27              692638
# 28              512705
# 29              385190
# 30              470151
# 31              459387
# 32              638185
# 33              930164
# 34                 NaN
# 35              594393
# 36              442427
# 37                 NaN
# 38              136281
# 39              177796
# 40              177115
# 41              207605
# 42              210637
# 43              300744
# 44              490936
# 45              337412
# 46              274319
# 47                 NaN
# 48              259159
#
# [48 rows x 312 columns]

# %%
#properties_t = properties_t.head().drop(0)

# %%
properties_t = properties_t.drop(0)

# %%
properties_t.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2020-01-01 00:00:00, 2020-02-01 00:00:00, 2020-03-01 00:00:00,
#        2020-04-01 00:00:00, 2020-05-01 00:00:00, 2020-06-01 00:00:00,
#        2020-07-01 00:00:00, 2020-08-01 00:00:00, 2020-09-01 00:00:00,
#        2020-10-01 00:00:00],
#       dtype='object', name=0, length=312)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
pclean = pd.melt(properties_t, id_vars = ['London_Borough','ID'])

# %%
pclean.head()
# Out:
#        London_Borough         ID          0    value
# 0      City of London  E09000001 1995-01-01    91449
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2              Barnet  E09000003 1995-01-01  93284.5
# 3              Bexley  E09000004 1995-01-01  64958.1
# 4               Brent  E09000005 1995-01-01  71306.6

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
pclean.columns
# Out:
# Index(['London_Borough', 'ID', 0, 'value'], dtype='object')

# %%
pclean = pclean.rename(columns = {0:'Month','value':'Average_price'})

# %%
pclean.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
pclean['Average_price'] = pd.to_numeric(pclean['Average_price'])

# %%
pclean
# Out:
#            London_Borough         ID      Month  Average_price
# 0          City of London  E09000001 1995-01-01    91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                  Barnet  E09000003 1995-01-01    93284.51832
# 3                  Bexley  E09000004 1995-01-01    64958.09036
# 4                   Brent  E09000005 1995-01-01    71306.56698
# ...                   ...        ...        ...            ...
# 14875              LONDON  E12000007 2020-10-01   490935.92630
# 14876          SOUTH EAST  E12000008 2020-10-01   337412.19800
# 14877          SOUTH WEST  E12000009 2020-10-01   274319.43460
# 14878         Unnamed: 47        NaN 2020-10-01            NaN
# 14879             England  E92000001 2020-10-01   259158.77180
#
# [14880 rows x 4 columns]

# %%
pclean.count()
# Out:
# London_Borough    14880
# ID                13950
# Month             14880
# Average_price     13950
# dtype: int64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
pclean['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
pclean[pclean['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
pclean[pclean['ID'].isna()]
# Out:
#       London_Borough   ID      Month  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# ...              ...  ...        ...            ...
# 14820    Unnamed: 37  NaN 2020-09-01            NaN
# 14830    Unnamed: 47  NaN 2020-09-01            NaN
# 14865    Unnamed: 34  NaN 2020-10-01            NaN
# 14868    Unnamed: 37  NaN 2020-10-01            NaN
# 14878    Unnamed: 47  NaN 2020-10-01            NaN
#
# [930 rows x 4 columns]

# %%
pdropped = pclean[pclean['Average_price'].notna()]
pdropped.head(48)
# Out:
#           London_Borough         ID      Month  Average_price  Year
# 0         City of London  E09000001 1995-01-01    91448.98487  1995
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2                 Barnet  E09000003 1995-01-01    93284.51832  1995
# 3                 Bexley  E09000004 1995-01-01    64958.09036  1995
# 4                  Brent  E09000005 1995-01-01    71306.56698  1995
# 5                Bromley  E09000006 1995-01-01    81671.47692  1995
# 6                 Camden  E09000007 1995-01-01   120932.88810  1995
# 7                Croydon  E09000008 1995-01-01    69158.16225  1995
# 8                 Ealing  E09000009 1995-01-01    79885.89069  1995
# 9                Enfield  E09000010 1995-01-01    72514.69096  1995
# 10             Greenwich  E09000011 1995-01-01    62300.10169  1995
# 11               Hackney  E09000012 1995-01-01    61296.52637  1995
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020  1995
# 13              Haringey  E09000014 1995-01-01    76287.56947  1995
# 14                Harrow  E09000015 1995-01-01    84769.52599  1995
# 15              Havering  E09000016 1995-01-01    68000.13774  1995
# 16            Hillingdon  E09000017 1995-01-01    73834.82964  1995
# 17              Hounslow  E09000018 1995-01-01    72231.70537  1995
# 18             Islington  E09000019 1995-01-01    92516.48557  1995
# 19  Kensington & Chelsea  E09000020 1995-01-01   182694.83260  1995
# 20  Kingston upon Thames  E09000021 1995-01-01    80875.84843  1995
# 21               Lambeth  E09000022 1995-01-01    67770.98843  1995
# 22              Lewisham  E09000023 1995-01-01    60491.26109  1995
# 23                Merton  E09000024 1995-01-01    82070.61330  1995
# 24                Newham  E09000025 1995-01-01    53539.31919  1995
# 25             Redbridge  E09000026 1995-01-01    72189.58437  1995
# 26  Richmond upon Thames  E09000027 1995-01-01   109326.12450  1995
# 27             Southwark  E09000028 1995-01-01    67885.20344  1995
# 28                Sutton  E09000029 1995-01-01    71536.97357  1995
# 29         Tower Hamlets  E09000030 1995-01-01    59865.18995  1995
# 30        Waltham Forest  E09000031 1995-01-01    61319.44913  1995
# 31            Wandsworth  E09000032 1995-01-01    88559.04381  1995
# 32           Westminster  E09000033 1995-01-01   133025.27720  1995
# 34          Inner London  E13000001 1995-01-01    78251.97650  1995
# 35          Outer London  E13000002 1995-01-01    72958.79836  1995
# 37            NORTH EAST  E12000001 1995-01-01    42076.35411  1995
# 38            NORTH WEST  E12000002 1995-01-01    43958.48001  1995
# 39    YORKS & THE HUMBER  E12000003 1995-01-01    44803.42878  1995
# 40         EAST MIDLANDS  E12000004 1995-01-01    45544.52227  1995
# 41         WEST MIDLANDS  E12000005 1995-01-01    48527.52339  1995
# 42       EAST OF ENGLAND  E12000006 1995-01-01    56701.59610  1995
# 43                LONDON  E12000007 1995-01-01    74435.76052  1995
# 44            SOUTH EAST  E12000008 1995-01-01    64018.87894  1995
# 45            SOUTH WEST  E12000009 1995-01-01    54705.15790  1995
# 47               England  E92000001 1995-01-01    53202.77128  1995
# 48        City of London  E09000001 1995-02-01    82202.77314  1995
# 49    Barking & Dagenham  E09000002 1995-02-01    51085.77983  1995
# 50                Barnet  E09000003 1995-02-01    93190.16963  1995

# %%
pdropped.count()
# Out:
# London_Borough    13950
# ID                13950
# Month             13950
# Average_price     13950
# Year              13950
# dtype: int64

# %%
pdropped['London_Borough'].unique
# Out:
# <bound method Series.unique of 0            City of London
# 1        Barking & Dagenham
# 2                    Barnet
# 3                    Bexley
# 4                     Brent
#                 ...
# 14874       EAST OF ENGLAND
# 14875                LONDON
# 14876            SOUTH EAST
# 14877            SOUTH WEST
# 14879               England
# Name: London_Borough, Length: 13950, dtype: object>

# %%
print(pclean.dtypes)
print(pdropped.dtypes)
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# Year                       int64
# dtype: object
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# Year                       int64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
pdropped[pdropped['London_Borough'] == 'City of London'].plot(kind='line', x = 'Month', y = 'Average_price')
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
pdropped['Year'] = pdropped['Month'].apply(lambda t: t.year)
# Out:
# <ipython-input-107-5d2bf1ada4fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdropped['Year'] = pdropped['Month'].apply(lambda t: t.year).copy()

# %%
pdropped
# Out:
#            London_Borough         ID      Month  Average_price  Year
# 0          City of London  E09000001 1995-01-01    91448.98487  1995
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2                  Barnet  E09000003 1995-01-01    93284.51832  1995
# 3                  Bexley  E09000004 1995-01-01    64958.09036  1995
# 4                   Brent  E09000005 1995-01-01    71306.56698  1995
# ...                   ...        ...        ...            ...   ...
# 14874     EAST OF ENGLAND  E12000006 2020-10-01   300744.21180  2020
# 14875              LONDON  E12000007 2020-10-01   490935.92630  2020
# 14876          SOUTH EAST  E12000008 2020-10-01   337412.19800  2020
# 14877          SOUTH WEST  E12000009 2020-10-01   274319.43460  2020
# 14879             England  E92000001 2020-10-01   259158.77180  2020
#
# [13950 rows x 5 columns]

# %%
pdropped[pdropped['London_Borough'] == 'City of London'].plot(kind='line', x = 'Year', y = 'Average_price')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
dfg = pdropped.groupby(by=['London_Borough', 'Year']).mean('Average_price').reset_index()

# %%
dfg.index
# Out:
# RangeIndex(start=0, stop=1170, step=1)

# %%
dfg['London_Borough']
# Out:
# 0       Barking & Dagenham
# 1       Barking & Dagenham
# 2       Barking & Dagenham
# 3       Barking & Dagenham
# 4       Barking & Dagenham
#                ...
# 1165    YORKS & THE HUMBER
# 1166    YORKS & THE HUMBER
# 1167    YORKS & THE HUMBER
# 1168    YORKS & THE HUMBER
# 1169    YORKS & THE HUMBER
# Name: London_Borough, Length: 1170, dtype: object

# %%
pdropped['London_Borough']
# Out:
# 0            City of London
# 1        Barking & Dagenham
# 2                    Barnet
# 3                    Bexley
# 4                     Brent
#                 ...
# 14874       EAST OF ENGLAND
# 14875                LONDON
# 14876            SOUTH EAST
# 14877            SOUTH WEST
# 14879               England
# Name: London_Borough, Length: 13950, dtype: object

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2018 = float(d['Average_price'][d['Year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
create_price_ratio(dfg[dfg['London_Borough']=='YORKS & THE HUMBER'])
# Out:
# [3.356065086028382]

# %%
final={}

# %%
for b in dfg['London_Borough'].unique():
    # Let's make our parameter to our create_price_ratio function: i.e., we subset dfg on 'London_Borough' == b. 
    borough = dfg[dfg['London_Borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling create_price_ratio with the argument: borough
    final[b] = create_price_ratio(borough)
# We use the function and incorporate that into a new key of the dictionary 
print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'EAST MIDLANDS': [3.6327346720877034], 'EAST OF ENGLAND': [4.166900547724156], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'England': [3.8104529783974], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Inner London': [5.170857506254785], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'LONDON': [4.679776249632861], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'NORTH EAST': [2.828080506434263], 'NORTH WEST': [3.3634156376540654], 'Newham': [5.305390437201879], 'Outer London': [4.418949809440314], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'SOUTH EAST': [3.8283877112840563], 'SOUTH WEST': [3.795497124092444], 'Southwark': [5.516485302379376], 'Sutton': [4.118522608573157], 'Tower Hamlets': [4.62670104006116], 'WEST MIDLANDS': [3.3112621931400104], 'Waltham Forest': [5.83475580932281], 'Wandsworth': [4.757709347739269], 'Westminster': [5.353565392605413], 'YORKS & THE HUMBER': [3.356065086028382]}

# %%
dfg.columns
# Out:
# Index(['London_Borough', 'Year', 'Average_price'], dtype='object')

# %%
type(dfg['Average_price'])
# Out:
# pandas.core.series.Series

# %%
pfinal = pd.DataFrame(final)

# %%
pfinal.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon  EAST MIDLANDS  EAST OF ENGLAND  ...  SOUTH EAST  \
# 0         5.30162   4.2011       3.632735         4.166901  ...    3.828388
#
#    SOUTH WEST  Southwark    Sutton  Tower Hamlets  WEST MIDLANDS  \
# 0    3.795497   5.516485  4.118523       4.626701       3.311262
#
#    Waltham Forest  Wandsworth  Westminster  YORKS & THE HUMBER
# 0        5.834756    4.757709     5.353565            3.356065
#
# [1 rows x 45 columns]

# %%
pfinal_t = pfinal.transpose().reset_index()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
type(pfinal_t)
# Out:
# pandas.core.frame.DataFrame

# %%
pfinal_t.rename(columns={'index':'Borough', 0:'Price Ratio'}, inplace=True)

# %%
pfinal_t.head()
# Out:
#               Borough  Price Ratio
# 0  Barking & Dagenham     4.896619
# 1              Barnet     4.358196
# 2              Bexley     4.248977
# 3               Brent     4.894554
# 4             Bromley     4.094785

# %%
top15 = pfinal_t.sort_values(by='Price Ratio', ascending=False).head(15)
print(top15)
# Out:
#                  Borough  Price Ratio
# 14               Hackney     6.198286
# 41        Waltham Forest     5.834756
# 37             Southwark     5.516485
# 27              Lewisham     5.449221
# 43           Westminster     5.353565
# 31                Newham     5.305390
# 6         City of London     5.301620
# 21          Inner London     5.170858
# 16              Haringey     5.134625
# 23  Kensington & Chelsea     5.082465
# 26               Lambeth     4.957751
# 5                 Camden     4.935353
# 0     Barking & Dagenham     4.896619
# 3                  Brent     4.894554
# 22             Islington     4.844048

# %%
top15[['Borough','Price Ratio']].plot(kind='bar').set_xticklabels(top15.Borough)
plt.show()

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
